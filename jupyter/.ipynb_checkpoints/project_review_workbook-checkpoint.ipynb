# %% [markdown]
# # MasterMind AI Project Workbook
#
# This notebook gives you a Jupyter-friendly way to explore, run, and review the project without replacing the original Python package structure.
#
# Recommended use:
# - Keep the production code in `src/`, `templates/`, `static/`, and `tests/`
# - Use this notebook for exploration, demo prep, validation, and project review
# - Do not move the Flask API into notebook cells unless you only want a classroom demo

# %% [markdown]
# ## 1. Setup
#
# Run this first. It adds the project root to `sys.path` so notebook cells can import your existing modules.

# %%
from pathlib import Path
import sys
import os

NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = NOTEBOOK_DIR.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print('Notebook dir :', NOTEBOOK_DIR)
print('Project root :', PROJECT_ROOT)
print('Python path ok:', str(PROJECT_ROOT) in sys.path)

# %% [markdown]
# ## 2. Quick Project Map

# %%
important_paths = [
    'app.py',
    'configs/config.py',
    'src/data_pipeline.py',
    'src/feature_engineering.py',
    'src/models/train.py',
    'src/explainability.py',
    'src/fairness_audit.py',
    'src/api/app.py',
    'tests/test_api.py',
]

for rel in important_paths:
    path = PROJECT_ROOT / rel
    print(f'{rel:30} ->', 'FOUND' if path.exists() else 'MISSING')

# %% [markdown]
# ## 3. Import Core Modules

# %%
from configs.config import APPROVE_THRESHOLD, DECLINE_THRESHOLD, MODEL_VERSIONS
from src.api.app import create_app, determine_coverage_tier, validate_payload
from src.models.train import train_models
from src.explainability import render_reason

print('Approve threshold :', APPROVE_THRESHOLD)
print('Decline threshold :', DECLINE_THRESHOLD)
print('Model versions    :', MODEL_VERSIONS)

# %% [markdown]
# ## 4. Run Training Report
#
# This uses your existing training code. If real processed/raw data is present, it will use that. Otherwise it falls back to synthetic data, exactly like your Python module.

# %%
report = train_models(
    artifact_dir=str(PROJECT_ROOT / 'artifacts'),
    processed_dir=str(PROJECT_ROOT / 'data' / 'processed'),
    raw_dir=str(PROJECT_ROOT / 'data' / 'raw'),
)

report

# %% [markdown]
# ## 5. Start the Flask App in Notebook Context
#
# This does not start the server process. It creates the Flask app object so you can test routes with Flask's test client.

# %%
app = create_app()
client = app.test_client()

health_response = client.get('/health')
print('Status code:', health_response.status_code)
health_response.get_json()

# %% [markdown]
# ## 6. Build a Sample REDUCED Payload

# %%
sample_reduced_payload = {
    'application': {
        'AMT_INCOME_TOTAL_CAPPED': 120000.0,
        'AMT_CREDIT': 250000.0,
        'AMT_ANNUITY': 25000.0,
        'AMT_GOODS_PRICE': 220000.0,
        'DAYS_BIRTH': -12000.0,
        'DAYS_EMPLOYED': -1500.0,
        'DAYS_REGISTRATION': -3000.0,
        'DAYS_ID_PUBLISH': -2000.0,
        'DAYS_LAST_PHONE_CHANGE': -1000.0,
        'REGION_POPULATION_RELATIVE': 0.02,
        'EXT_SOURCE_1': 0.2,
        'EXT_SOURCE_2': 0.4,
        'EXT_SOURCE_3': 0.6,
        'CNT_FAM_MEMBERS': 2.0,
        'OWN_CAR_AGE': 5.0,
        'OBS_30_CNT_SOCIAL_CIRCLE': 1.0,
        'DEF_30_CNT_SOCIAL_CIRCLE': 0.0,
        'OBS_60_CNT_SOCIAL_CIRCLE': 1.0,
        'DEF_60_CNT_SOCIAL_CIRCLE': 0.0,
        'AMT_REQ_CREDIT_BUREAU_HOUR': 0.0,
        'AMT_REQ_CREDIT_BUREAU_DAY': 0.0,
        'AMT_REQ_CREDIT_BUREAU_WEEK': 1.0,
        'AMT_REQ_CREDIT_BUREAU_MON': 1.0,
        'AMT_REQ_CREDIT_BUREAU_QRT': 0.0,
        'AMT_REQ_CREDIT_BUREAU_YEAR': 1.0,
        'NAME_CONTRACT_TYPE': 'Cash loans',
        'NAME_TYPE_SUITE': 'Unaccompanied',
        'NAME_EDUCATION_TYPE': 'Higher education',
        'NAME_FAMILY_STATUS': 'Married',
        'OCCUPATION_TYPE': 'Laborers',
        'ORGANIZATION_TYPE': 'Business Entity Type 3',
        'WEEKDAY_APPR_PROCESS_START': 'MONDAY',
        'DAYS_EMPLOYED_ANOM': 0
    }
}

print('Tier:', determine_coverage_tier(sample_reduced_payload))
print('Validation:', validate_payload(sample_reduced_payload))

# %% [markdown]
# ## 7. Score the Sample Payload

# %%
score_response = client.post('/score', json=sample_reduced_payload)
print('Status code:', score_response.status_code)
score_response.get_json()

# %% [markdown]
# ## 8. Project Review Notes
#
# Use this cell to keep your guide discussion points in one place.

# %%
review_notes = {
    'strengths': [
        'Modular pipeline across data, features, model, explainability, fairness, and API',
        'Good separation between training-time and runtime code',
        'Real product direction with Flask UI and health endpoint'
    ],
    'improvements': [
        'Align FULL UI payload with FULL backend contract',
        'Add real API tests in tests/test_api.py',
        'Fix documentation mismatches between report and code',
        'Tighten fairness audit and artifact status flow'
    ],
    'feature_ideas': [
        'Batch scoring with CSV upload',
        'Threshold simulation dashboard',
        'Drift monitoring report',
        'Applicant what-if analysis'
    ]
}

review_notes

# %% [markdown]
# ## 9. Guide Questions
#
# These are the questions you can discuss before adding a new feature.

# %%
guide_questions = [
    'Should I first improve testing, UI-backend consistency, and documentation before adding a new feature?',
    'Do you want this project evaluated more as an ML system, a software system, or a product prototype?',
    'Would batch scoring be a meaningful extension, or is it outside the expected scope?',
    'Would a threshold simulation dashboard be valuable for showing business understanding?',
    'Would drift monitoring and data-quality monitoring be useful, or would that be overkill?',
    'Would a what-if analysis feature be considered relevant or too advanced for this stage?',
    'Should I focus more on stronger validation and testing, or on one more visible feature?',
    'Which final improvement would you recommend: batch scoring, threshold simulation, drift monitoring, or what-if analysis?'
]

for i, question in enumerate(guide_questions, start=1):
    print(f'{i}. {question}')

# %% [markdown]
# ## 10. Recommendation
#
# You can convert **parts** of this project into notebooks very well:
# - EDA
# - feature engineering demos
# - training experiments
# - explainability plots
# - fairness review
# - API testing with Flask test client
#
# You should usually keep these as normal `.py` files:
# - Flask app entrypoints
# - reusable feature builders
# - production API code
# - tests
#
# Best practice is hybrid: keep the real system as code, and use notebooks for presentation, analysis, and experimentation.
